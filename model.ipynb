# %% [markdown]
# ## Sentiment analysis

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
import string
from scipy import sparse
from textblob import TextBlob
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
import xgboost as xgb
from sklearn.metrics import accuracy_score

# %%
#load data
df = pd.concat([pd.read_csv("reviews_rt.csv", sep="|"), 
        pd.read_csv("imdb_small.csv", sep="|")], ignore_index=True, copy=False)
df = shuffle(df)
df = df.reset_index(drop=True)
print('Dataset loaded.')
print('Dataset has the following number of positive/negative reviews:')
print(df.label.value_counts())
# Out:
# Dataset loaded.
# Dataset has the following number of positive/negative reviews:
# 1    89658
# 0    62952
# Name: label, dtype: int64

# %%
#split into train and test
train, test = train_test_split(df, train_size = 0.7, random_state = 111, stratify=df.label)
del df

# %%
#remove duplicate
train = train.drop_duplicates()

#reset indices
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)
print('Train and test sets are ready.')
print('Train set has',train.shape[0],'observations.')
print('Test set has',test.shape[0],'observations.')
# Out:
# Train and test sets are ready.
# Train set has 106436 observations.
# Test set has 45783 observations.

# %%
#regular expressions replacer
import re
replacement_patterns = [
#reductions
(r'won\'t', 'will not'),
(r'can\'t', 'cannot'),
(r'i\'m', 'i am'),
(r'ain\'t', 'is not'),
(r'(\w+)\'ll', '\g<1> will'),
(r'(\w+)n\'t', '\g<1> not'),
(r'(\w+)\'ve', '\g<1> have'),
(r'(\w+)\'s', '\g<1> is'),
(r'(\w+)\'re', '\g<1> are'),
(r'(\w+)\'d', '\g<1> would'),
#auotes at the beginig and end
(r'^["\'](.+)["\']$','\g<1>'),
#identity nouns - names of films and actors
(r'["\'].+?["\']',''),
(r'(\w+)\s+[A-Z][a-z]+','\g<1>'),
(r'(\w+)\s+[A-Z][a-z]+','\g<1>'),
#removing brackets
(r'[\[\(\)\]]',''),
#removing dates
(r' [\']?\d{2,4}s? ',' ')
]

def replace(text):
    for (pattern, repl) in replacement_patterns:
        text = re.sub(pattern, repl, text)
    return text

# %%
#tokenizer
stopwords_list = stopwords.words('english')  
def tokenize_text(text):
    replaced = replace(text).lower()
    words = word_tokenize(replaced)
    words = [SnowballStemmer('english').stem(w) for w in words]
    words = [word for word in words if word not in stopwords_list]
    return words

#vectorization
def build_feature_matrices(X):
    vectorizer = CountVectorizer(tokenizer=tokenize_text, max_features=6000, ngram_range=(1,2))
    X_transform = vectorizer.fit_transform(X).toarray()
    features_voc = vectorizer.get_feature_names()
    return X_transform, features_voc

def build_feature_matrices_test(X):
    vectorizer = CountVectorizer(tokenizer=tokenize_text, vocabulary = features)
    X_transform = vectorizer.fit_transform(X).toarray()
    return X_transform

# %%
#Train set transformation
print('Train set:')
print('Vectorizing set...')
X_train_transform, features = build_feature_matrices(train['text'])

#NEW FEATURES
print('Extracting features...')
#review length
X_train_transform = np.insert(X_train_transform, 0, train.text.apply(lambda s: len(s)), axis=1)
#Number of exclamation marks
X_train_transform = np.insert(X_train_transform, 0, train.text.apply(lambda s: len([x for x in s if x=='!'])), axis=1)
#Number of questions marks
X_train_transform = np.insert(X_train_transform, 0, train.text.apply(lambda s: len([x for x in s if x=='?'])), axis=1)
#Number of tokens
X_train_transform = np.insert(X_train_transform, 0, train.text.apply(lambda s: len(word_tokenize(s))), axis=1)
#Number of sentences
X_train_transform = np.insert(X_train_transform, 0, train.text.apply(lambda s: len(sent_tokenize(s))), axis=1)
#sentence polarity
X_train_transform = np.insert(X_train_transform, 0, 
            train.text.apply(lambda s: TextBlob(sent_tokenize(s)[0]).sentiment.polarity), axis=1)
X_train_transform = np.insert(X_train_transform, 0, 
            train.text.apply(lambda s: TextBlob(sent_tokenize(s)[-1]).sentiment.polarity), axis=1)

print("X matrix has", X_train_transform.shape[1], "variables.")

#to sparse
X_train_transform = sparse.csr_matrix(X_train_transform)
# Out:
# Train set:
# Vectorizing set...
# Extracting features...
# X matrix has 6007 variables.

# %%
#Test set transformation
print('Test set:')
print('Vectorizing set...')
X_test_transform = build_feature_matrices_test(test['text'])

#NEW FEATURES
print('Extracting features...')
X_test_transform = np.insert(X_test_transform, 0, test.text.apply(lambda s: len(s)), axis=1)
X_test_transform = np.insert(X_test_transform, 0, test.text.apply(lambda s: len([x for x in s if x=='!'])), axis=1)
X_test_transform = np.insert(X_test_transform, 0, test.text.apply(lambda s: len([x for x in s if x=='?'])), axis=1)
X_test_transform = np.insert(X_test_transform, 0, test.text.apply(lambda s: len(word_tokenize(s))), axis=1)
X_test_transform = np.insert(X_test_transform, 0, test.text.apply(lambda s: len(sent_tokenize(s))), axis=1)
X_test_transform = np.insert(X_test_transform, 0, 
            test.text.apply(lambda s: TextBlob(sent_tokenize(s)[0]).sentiment.polarity), axis=1)
X_test_transform = np.insert(X_test_transform, 0, 
            test.text.apply(lambda s: TextBlob(sent_tokenize(s)[-1]).sentiment.polarity), axis=1)

print("X matrix has", X_test_transform.shape[1], "variables.")

#to sparse
X_test_transform = sparse.csr_matrix(X_test_transform)
# Out:
# Test set:
# Vectorizing set...
# Extracting features...
# X matrix has 6007 variables.

# %%
#connvert data to xgb format
dtrain = xgb.DMatrix(X_train_transform,label=train['label'])
dtest = xgb.DMatrix(X_test_transform[25000:],label=test['label'][25000:])
dval = xgb.DMatrix(X_test_transform[:25000],label=test['label'][:25000])
del X_train_transform,X_test_transform
print("Datasets were converted to xgb format.")
# Out:
# Datasets were converted to xgb format.

# %%
#set parameters
param = {
        'eta': 0.2,
        'objective':'binary:logistic',
        'max_depth':15,
        'seed':123,
        'eval_metric':'error',
        'min_child_weight':7
        }

# %%
#train and evaluation set
evallist  = [(dval,'eval'), (dtrain,'train')]

#train model
num_round = 1000
print("Model training...")
bst = xgb.train(param, dtrain, num_round, evallist)
print("Done.")
# Out:
# Model training...
# [0]	eval-error:0.31752	train-error:0.301289
# [1]	eval-error:0.30932	train-error:0.292223
# [2]	eval-error:0.30556	train-error:0.286059
# [3]	eval-error:0.30404	train-error:0.283748
# [4]	eval-error:0.3014	train-error:0.280244
# [5]	eval-error:0.2994	train-error:0.278581
# [6]	eval-error:0.2946	train-error:0.272389
# [7]	eval-error:0.29372	train-error:0.270003
# [8]	eval-error:0.29096	train-error:0.266348
# [9]	eval-error:0.289	train-error:0.262073
# [10]	eval-error:0.28628	train-error:0.259602
# [11]	eval-error:0.28352	train-error:0.255365
# [12]	eval-error:0.281	train-error:0.252903
# [13]	eval-error:0.2792	train-error:0.249681
# [14]	eval-error:0.2772	train-error:0.247557
# [15]	eval-error:0.276	train-error:0.245622
# [16]	eval-error:0.27412	train-error:0.243451
# [17]	eval-error:0.27216	train-error:0.242268
# [18]	eval-error:0.27116	train-error:0.240605
# [19]	eval-error:0.27076	train-error:0.238716
# [20]	eval-error:0.26936	train-error:0.23773
# [21]	eval-error:0.2674	train-error:0.235193
# [22]	eval-error:0.26644	train-error:0.234338
# [23]	eval-error:0.26612	train-error:0.232384
# [24]	eval-error:0.2648	train-error:0.230242
# [25]	eval-error:0.26276	train-error:0.228146
# [26]	eval-error:0.26168	train-error:0.226314
# [27]	eval-error:0.26136	train-error:0.224614
# [28]	eval-error:0.25988	train-error:0.22327
# [29]	eval-error:0.25968	train-error:0.222631
# [30]	eval-error:0.2586	train-error:0.221203
# [31]	eval-error:0.25756	train-error:0.220424
# [32]	eval-error:0.25604	train-error:0.219531
# [33]	eval-error:0.255	train-error:0.218817
# [34]	eval-error:0.25496	train-error:0.217445
# [35]	eval-error:0.2542	train-error:0.216506
# [36]	eval-error:0.25328	train-error:0.215491
# [37]	eval-error:0.2516	train-error:0.214335
# [38]	eval-error:0.2508	train-error:0.213424
# [39]	eval-error:0.2502	train-error:0.212766
# [40]	eval-error:0.24996	train-error:0.211883
# [41]	eval-error:0.2492	train-error:0.211075
# [42]	eval-error:0.24832	train-error:0.210211
# [43]	eval-error:0.24776	train-error:0.209459
# [44]	eval-error:0.24724	train-error:0.208886
# [45]	eval-error:0.24724	train-error:0.207787
# [46]	eval-error:0.2468	train-error:0.206875
# [47]	eval-error:0.24612	train-error:0.206312
# [48]	eval-error:0.24616	train-error:0.205532
# [49]	eval-error:0.24592	train-error:0.205053
# [50]	eval-error:0.24456	train-error:0.204132
# [51]	eval-error:0.2442	train-error:0.203305
# [52]	eval-error:0.24356	train-error:0.202554
# [53]	eval-error:0.24336	train-error:0.201755
# [54]	eval-error:0.24324	train-error:0.200618
# [55]	eval-error:0.24256	train-error:0.199265
# [56]	eval-error:0.24136	train-error:0.198767
# [57]	eval-error:0.24148	train-error:0.197696
# [58]	eval-error:0.241	train-error:0.196879
# [59]	eval-error:0.24044	train-error:0.196306
# [60]	eval-error:0.24	train-error:0.195601
# [61]	eval-error:0.24016	train-error:0.195188
# [62]	eval-error:0.24024	train-error:0.194643
# [63]	eval-error:0.23924	train-error:0.193675
# [64]	eval-error:0.2394	train-error:0.193309
# [65]	eval-error:0.2392	train-error:0.193027
# [66]	eval-error:0.23836	train-error:0.192613
# [67]	eval-error:0.23776	train-error:0.191918
# [68]	eval-error:0.23744	train-error:0.191336
# [69]	eval-error:0.238	train-error:0.190396
# [70]	eval-error:0.23728	train-error:0.190048
# [71]	eval-error:0.23688	train-error:0.18878
# [72]	eval-error:0.23684	train-error:0.188273
# [73]	eval-error:0.23628	train-error:0.187822
# [74]	eval-error:0.23568	train-error:0.187155
# [75]	eval-error:0.23532	train-error:0.186394
# [76]	eval-error:0.23484	train-error:0.185971
# [77]	eval-error:0.23452	train-error:0.185501
# [78]	eval-error:0.234	train-error:0.184975
# [79]	eval-error:0.23364	train-error:0.184411
# [80]	eval-error:0.2336	train-error:0.183942
# [81]	eval-error:0.23344	train-error:0.183688
# [82]	eval-error:0.23252	train-error:0.183002
# [83]	eval-error:0.23244	train-error:0.182504
# [84]	eval-error:0.2322	train-error:0.182072
# [85]	eval-error:0.23192	train-error:0.180869
# [86]	eval-error:0.23128	train-error:0.180672
# [87]	eval-error:0.23112	train-error:0.180324
# [88]	eval-error:0.23068	train-error:0.179939
# [89]	eval-error:0.22988	train-error:0.179526
# [90]	eval-error:0.23016	train-error:0.179075
# [91]	eval-error:0.22988	train-error:0.178812
# [92]	eval-error:0.22984	train-error:0.178051
# [93]	eval-error:0.22984	train-error:0.177233
# [94]	eval-error:0.22968	train-error:0.176688
# [95]	eval-error:0.22884	train-error:0.176519
# [96]	eval-error:0.22856	train-error:0.176256
# [97]	eval-error:0.22824	train-error:0.175354
# [98]	eval-error:0.22856	train-error:0.175016
# [99]	eval-error:0.22804	train-error:0.174678
# [100]	eval-error:0.22796	train-error:0.174208
# [101]	eval-error:0.2274	train-error:0.17387
# [102]	eval-error:0.2268	train-error:0.173165
# [103]	eval-error:0.2268	train-error:0.172808
# [104]	eval-error:0.2268	train-error:0.172207
# [105]	eval-error:0.2264	train-error:0.171953
# [106]	eval-error:0.226	train-error:0.170863
# [107]	eval-error:0.22568	train-error:0.170478
# [108]	eval-error:0.22544	train-error:0.169952
# [109]	eval-error:0.22536	train-error:0.169576
# [110]	eval-error:0.22488	train-error:0.16921
# [111]	eval-error:0.22456	train-error:0.168928
# [112]	eval-error:0.22476	train-error:0.16843
# [113]	eval-error:0.22456	train-error:0.168336
# [114]	eval-error:0.22404	train-error:0.167876
# [115]	eval-error:0.2238	train-error:0.1675
# [116]	eval-error:0.22376	train-error:0.167227
# [117]	eval-error:0.22416	train-error:0.167002
# [118]	eval-error:0.22424	train-error:0.166654
# [119]	eval-error:0.22372	train-error:0.165987
# [120]	eval-error:0.22348	train-error:0.165752
# [121]	eval-error:0.2236	train-error:0.165405
# [122]	eval-error:0.22328	train-error:0.165245
# [123]	eval-error:0.22332	train-error:0.165057
# [124]	eval-error:0.223	train-error:0.164691
# [125]	eval-error:0.2228	train-error:0.164587
# [126]	eval-error:0.22304	train-error:0.164221
# [127]	eval-error:0.22248	train-error:0.163713
# [128]	eval-error:0.22252	train-error:0.163441
# [129]	eval-error:0.2224	train-error:0.163206
# [130]	eval-error:0.22224	train-error:0.162877
# [131]	eval-error:0.22212	train-error:0.162718
# [132]	eval-error:0.22224	train-error:0.162473
# [133]	eval-error:0.22196	train-error:0.162191
# [134]	eval-error:0.22172	train-error:0.161646
# [135]	eval-error:0.22116	train-error:0.161261
# [136]	eval-error:0.22108	train-error:0.161139
# [137]	eval-error:0.22112	train-error:0.160547
# [138]	eval-error:0.2202	train-error:0.160087
# [139]	eval-error:0.21972	train-error:0.15989
# [140]	eval-error:0.22012	train-error:0.159702
# [141]	eval-error:0.21964	train-error:0.159551
# [142]	eval-error:0.2194	train-error:0.159185
# [143]	eval-error:0.2196	train-error:0.158988
# [144]	eval-error:0.21968	train-error:0.158762
# [145]	eval-error:0.21976	train-error:0.15833
# [146]	eval-error:0.21976	train-error:0.15818
# [147]	eval-error:0.21976	train-error:0.157804
# [148]	eval-error:0.21908	train-error:0.157559
# [149]	eval-error:0.21884	train-error:0.157447
# [150]	eval-error:0.21888	train-error:0.157137
# [151]	eval-error:0.21896	train-error:0.157033
# [152]	eval-error:0.21876	train-error:0.156695
# [153]	eval-error:0.21884	train-error:0.156451
# [154]	eval-error:0.21904	train-error:0.156131
# [155]	eval-error:0.21896	train-error:0.155972
# [156]	eval-error:0.21848	train-error:0.15553
# [157]	eval-error:0.21852	train-error:0.155201
# [158]	eval-error:0.21804	train-error:0.154854
# [159]	eval-error:0.21792	train-error:0.154581
# [160]	eval-error:0.21756	train-error:0.15429
# [161]	eval-error:0.21768	train-error:0.154102
# [162]	eval-error:0.21764	train-error:0.154017
# [163]	eval-error:0.21748	train-error:0.153773
# [164]	eval-error:0.21744	train-error:0.15367
# [165]	eval-error:0.21756	train-error:0.153454
# [166]	eval-error:0.21756	train-error:0.153172
# [167]	eval-error:0.21808	train-error:0.152646
# [168]	eval-error:0.2176	train-error:0.152223
# [169]	eval-error:0.21716	train-error:0.151941
# [170]	eval-error:0.21752	train-error:0.151894
# [171]	eval-error:0.21756	train-error:0.151725
# [172]	eval-error:0.21732	train-error:0.150973
# [173]	eval-error:0.21748	train-error:0.150785
# [174]	eval-error:0.2174	train-error:0.150654
# [175]	eval-error:0.21736	train-error:0.150438
# [176]	eval-error:0.217	train-error:0.150363
# [177]	eval-error:0.2168	train-error:0.150165
# [178]	eval-error:0.21672	train-error:0.14994
# [179]	eval-error:0.21704	train-error:0.149583
# [180]	eval-error:0.217	train-error:0.149395
# [181]	eval-error:0.21716	train-error:0.149188
# [182]	eval-error:0.21736	train-error:0.148859
# [183]	eval-error:0.21704	train-error:0.148568
# [184]	eval-error:0.21664	train-error:0.148371
# [185]	eval-error:0.2166	train-error:0.148239
# [186]	eval-error:0.21628	train-error:0.147741
# [187]	eval-error:0.21624	train-error:0.147535
# [188]	eval-error:0.21668	train-error:0.146605
# [189]	eval-error:0.21676	train-error:0.146492
# [190]	eval-error:0.21644	train-error:0.146125
# [191]	eval-error:0.21628	train-error:0.145919
# [192]	eval-error:0.21604	train-error:0.14575
# [193]	eval-error:0.21652	train-error:0.145336
# [194]	eval-error:0.2166	train-error:0.14512
# [195]	eval-error:0.21656	train-error:0.144989
# [196]	eval-error:0.21636	train-error:0.144885
# [197]	eval-error:0.21628	train-error:0.144528
# [198]	eval-error:0.21636	train-error:0.144378
# [199]	eval-error:0.21616	train-error:0.144228
# [200]	eval-error:0.21596	train-error:0.144096
# [201]	eval-error:0.21564	train-error:0.143758
# [202]	eval-error:0.21596	train-error:0.143513
# [203]	eval-error:0.21616	train-error:0.143091
# [204]	eval-error:0.21592	train-error:0.14295
# [205]	eval-error:0.21564	train-error:0.142771
# [206]	eval-error:0.21504	train-error:0.142508
# [207]	eval-error:0.21504	train-error:0.142414
# [208]	eval-error:0.21504	train-error:0.142114
# [209]	eval-error:0.21536	train-error:0.141634
# [210]	eval-error:0.21544	train-error:0.141437
# [211]	eval-error:0.21528	train-error:0.141315
# [212]	eval-error:0.215	train-error:0.14124
# [213]	eval-error:0.21488	train-error:0.141108
# [214]	eval-error:0.21468	train-error:0.140939
# [215]	eval-error:0.21484	train-error:0.140873
# [216]	eval-error:0.21484	train-error:0.140639
# [217]	eval-error:0.21516	train-error:0.140469
# [218]	eval-error:0.21504	train-error:0.140159
# [219]	eval-error:0.21432	train-error:0.139953
# [220]	eval-error:0.21424	train-error:0.139492
# [221]	eval-error:0.21424	train-error:0.139257
# [222]	eval-error:0.214	train-error:0.138957
# [223]	eval-error:0.21396	train-error:0.138778
# [224]	eval-error:0.21432	train-error:0.138609
# [225]	eval-error:0.21424	train-error:0.138496
# [226]	eval-error:0.21392	train-error:0.138496
# [227]	eval-error:0.21392	train-error:0.138412
# [228]	eval-error:0.21444	train-error:0.138017
# [229]	eval-error:0.21464	train-error:0.137876
# [230]	eval-error:0.21428	train-error:0.137482
# [231]	eval-error:0.21424	train-error:0.137275
# [232]	eval-error:0.21412	train-error:0.137087
# [233]	eval-error:0.21368	train-error:0.136852
# [234]	eval-error:0.2136	train-error:0.136739
# [235]	eval-error:0.21372	train-error:0.136655
# [236]	eval-error:0.21368	train-error:0.136589
# [237]	eval-error:0.2138	train-error:0.136467
# [238]	eval-error:0.21376	train-error:0.136317
# [239]	eval-error:0.21376	train-error:0.136157
# [240]	eval-error:0.21392	train-error:0.135762
# [241]	eval-error:0.21384	train-error:0.13565
# [242]	eval-error:0.21372	train-error:0.135556
# [243]	eval-error:0.21356	train-error:0.135433
# [244]	eval-error:0.2136	train-error:0.135283
# [245]	eval-error:0.21344	train-error:0.135048
# [246]	eval-error:0.2134	train-error:0.134954
# [247]	eval-error:0.2134	train-error:0.134682
# [248]	eval-error:0.2134	train-error:0.134579
# [249]	eval-error:0.2136	train-error:0.134391
# [250]	eval-error:0.21356	train-error:0.134175
# [251]	eval-error:0.21348	train-error:0.133968
# [252]	eval-error:0.21332	train-error:0.133855
# [253]	eval-error:0.2132	train-error:0.133733
# [254]	eval-error:0.213	train-error:0.133573
# [255]	eval-error:0.21276	train-error:0.133357
# [256]	eval-error:0.21284	train-error:0.133376
# [257]	eval-error:0.21304	train-error:0.133291
# [258]	eval-error:0.21312	train-error:0.133056
# [259]	eval-error:0.21296	train-error:0.132953
# [260]	eval-error:0.2128	train-error:0.132906
# [261]	eval-error:0.21252	train-error:0.132521
# [262]	eval-error:0.21216	train-error:0.132136
# [263]	eval-error:0.21204	train-error:0.132061
# [264]	eval-error:0.21232	train-error:0.131985
# [265]	eval-error:0.21256	train-error:0.131957
# [266]	eval-error:0.21248	train-error:0.131798
# [267]	eval-error:0.21252	train-error:0.13161
# [268]	eval-error:0.2126	train-error:0.131328
# [269]	eval-error:0.212	train-error:0.131159
# [270]	eval-error:0.21204	train-error:0.131027
# [271]	eval-error:0.212	train-error:0.13099
# [272]	eval-error:0.21188	train-error:0.130896
# [273]	eval-error:0.21176	train-error:0.130698
# [274]	eval-error:0.21216	train-error:0.130398
# [275]	eval-error:0.21208	train-error:0.130332
# [276]	eval-error:0.21204	train-error:0.130153
# [277]	eval-error:0.21208	train-error:0.130012
# [278]	eval-error:0.21164	train-error:0.129749
# [279]	eval-error:0.21152	train-error:0.129721
# [280]	eval-error:0.2114	train-error:0.12959
# [281]	eval-error:0.21132	train-error:0.129458
# [282]	eval-error:0.2112	train-error:0.129317
# [283]	eval-error:0.21096	train-error:0.129298
# [284]	eval-error:0.21116	train-error:0.129167
# [285]	eval-error:0.21112	train-error:0.129101
# [286]	eval-error:0.21104	train-error:0.129082
# [287]	eval-error:0.21096	train-error:0.128951
# [288]	eval-error:0.211	train-error:0.128998
# [289]	eval-error:0.21116	train-error:0.12896
# [290]	eval-error:0.21096	train-error:0.128876
# [291]	eval-error:0.21084	train-error:0.128782
# [292]	eval-error:0.21084	train-error:0.128547
# [293]	eval-error:0.21092	train-error:0.128218
# [294]	eval-error:0.21084	train-error:0.12819
# [295]	eval-error:0.21088	train-error:0.128143
# [296]	eval-error:0.21108	train-error:0.127889
# [297]	eval-error:0.21092	train-error:0.127673
# [298]	eval-error:0.21092	train-error:0.127532
# [299]	eval-error:0.21096	train-error:0.127344
# [300]	eval-error:0.21052	train-error:0.127137
# [301]	eval-error:0.21072	train-error:0.126978
# [302]	eval-error:0.21096	train-error:0.126696
# [303]	eval-error:0.21108	train-error:0.126668
# [304]	eval-error:0.2112	train-error:0.126405
# [305]	eval-error:0.21148	train-error:0.126198
# [306]	eval-error:0.21156	train-error:0.125982
# [307]	eval-error:0.21136	train-error:0.125747
# [308]	eval-error:0.21144	train-error:0.125653
# [309]	eval-error:0.2116	train-error:0.12555
# [310]	eval-error:0.21172	train-error:0.125371
# [311]	eval-error:0.21148	train-error:0.125268
# [312]	eval-error:0.2114	train-error:0.12524
# [313]	eval-error:0.2112	train-error:0.125136
# [314]	eval-error:0.21124	train-error:0.125005
# [315]	eval-error:0.21128	train-error:0.124807
# [316]	eval-error:0.2114	train-error:0.124666
# [317]	eval-error:0.21132	train-error:0.124526
# [318]	eval-error:0.21112	train-error:0.124516
# [319]	eval-error:0.21108	train-error:0.124516
# [320]	eval-error:0.211	train-error:0.124347
# [321]	eval-error:0.21084	train-error:0.124056
# [322]	eval-error:0.2108	train-error:0.124037
# [323]	eval-error:0.21088	train-error:0.123999
# [324]	eval-error:0.21072	train-error:0.123896
# [325]	eval-error:0.21056	train-error:0.12383
# [326]	eval-error:0.2104	train-error:0.123774
# [327]	eval-error:0.2104	train-error:0.123718
# [328]	eval-error:0.21016	train-error:0.123774
# [329]	eval-error:0.21008	train-error:0.123689
# [330]	eval-error:0.21036	train-error:0.123577
# [331]	eval-error:0.2104	train-error:0.123295
# [332]	eval-error:0.21	train-error:0.123135
# [333]	eval-error:0.21	train-error:0.122919
# [334]	eval-error:0.21	train-error:0.122797
# [335]	eval-error:0.21	train-error:0.12274
# [336]	eval-error:0.2102	train-error:0.122703
# [337]	eval-error:0.20996	train-error:0.122581
# [338]	eval-error:0.20976	train-error:0.12259
# [339]	eval-error:0.2096	train-error:0.122421
# [340]	eval-error:0.20944	train-error:0.122299
# [341]	eval-error:0.20932	train-error:0.122205
# [342]	eval-error:0.20928	train-error:0.122092
# [343]	eval-error:0.20908	train-error:0.121763
# [344]	eval-error:0.20912	train-error:0.121557
# [345]	eval-error:0.20912	train-error:0.121463
# [346]	eval-error:0.20912	train-error:0.121406
# [347]	eval-error:0.20916	train-error:0.121284
# [348]	eval-error:0.2092	train-error:0.121237
# [349]	eval-error:0.20916	train-error:0.121181
# [350]	eval-error:0.209	train-error:0.121162
# [351]	eval-error:0.20888	train-error:0.121096
# [352]	eval-error:0.20856	train-error:0.121002
# [353]	eval-error:0.20856	train-error:0.121087
# [354]	eval-error:0.20884	train-error:0.121077
# [355]	eval-error:0.20868	train-error:0.120758
# [356]	eval-error:0.20856	train-error:0.120504
# [357]	eval-error:0.2086	train-error:0.120476
# [358]	eval-error:0.20868	train-error:0.120363
# [359]	eval-error:0.2088	train-error:0.120176
# [360]	eval-error:0.20856	train-error:0.120138
# [361]	eval-error:0.20856	train-error:0.12011
# [362]	eval-error:0.20836	train-error:0.120138
# [363]	eval-error:0.20836	train-error:0.120025
# [364]	eval-error:0.20792	train-error:0.119922
# [365]	eval-error:0.20796	train-error:0.119809
# [366]	eval-error:0.20792	train-error:0.119743
# [367]	eval-error:0.20788	train-error:0.119565
# [368]	eval-error:0.20792	train-error:0.119555
# [369]	eval-error:0.20784	train-error:0.119555
# [370]	eval-error:0.20816	train-error:0.119508
# [371]	eval-error:0.20824	train-error:0.119443
# [372]	eval-error:0.20816	train-error:0.119283
# [373]	eval-error:0.20796	train-error:0.11918
# [374]	eval-error:0.20792	train-error:0.119029
# [375]	eval-error:0.20808	train-error:0.118973
# [376]	eval-error:0.2082	train-error:0.118926
# [377]	eval-error:0.20804	train-error:0.11887
# [378]	eval-error:0.208	train-error:0.118776
# [379]	eval-error:0.20804	train-error:0.118719
# [380]	eval-error:0.20824	train-error:0.118635
# [381]	eval-error:0.20808	train-error:0.118503
# [382]	eval-error:0.20792	train-error:0.118409
# [383]	eval-error:0.20824	train-error:0.118212
# [384]	eval-error:0.20832	train-error:0.118099
# [385]	eval-error:0.2084	train-error:0.118024
# [386]	eval-error:0.20868	train-error:0.117855
# [387]	eval-error:0.20868	train-error:0.117845
# [388]	eval-error:0.20908	train-error:0.117564
# [389]	eval-error:0.20924	train-error:0.117357
# [390]	eval-error:0.20932	train-error:0.117037
# [391]	eval-error:0.2094	train-error:0.116925
# [392]	eval-error:0.20944	train-error:0.116821
# [393]	eval-error:0.20956	train-error:0.116774
# [394]	eval-error:0.20976	train-error:0.116586
# [395]	eval-error:0.20992	train-error:0.116474
# [396]	eval-error:0.2098	train-error:0.11638
# [397]	eval-error:0.20964	train-error:0.116258
# [398]	eval-error:0.20912	train-error:0.115985
# [399]	eval-error:0.20888	train-error:0.115788
# [400]	eval-error:0.20868	train-error:0.115685
# [401]	eval-error:0.20868	train-error:0.115609
# [402]	eval-error:0.20868	train-error:0.11545
# [403]	eval-error:0.20848	train-error:0.115252
# [404]	eval-error:0.2086	train-error:0.115243
# [405]	eval-error:0.20848	train-error:0.115121
# [406]	eval-error:0.20856	train-error:0.114999
# [407]	eval-error:0.20856	train-error:0.114924
# [408]	eval-error:0.20856	train-error:0.114745
# [409]	eval-error:0.20848	train-error:0.114717
# [410]	eval-error:0.20844	train-error:0.114651
# [411]	eval-error:0.20836	train-error:0.114623
# [412]	eval-error:0.20864	train-error:0.114548
# [413]	eval-error:0.20864	train-error:0.114463
# [414]	eval-error:0.20824	train-error:0.114322
# [415]	eval-error:0.20848	train-error:0.114191
# [416]	eval-error:0.2086	train-error:0.114087
# [417]	eval-error:0.20848	train-error:0.114087
# [418]	eval-error:0.20828	train-error:0.114022
# [419]	eval-error:0.20832	train-error:0.113862
# [420]	eval-error:0.20836	train-error:0.113824
# [421]	eval-error:0.20836	train-error:0.113759
# [422]	eval-error:0.20832	train-error:0.113749
# [423]	eval-error:0.20828	train-error:0.11374
# [424]	eval-error:0.20836	train-error:0.113646
# [425]	eval-error:0.20792	train-error:0.11343
# [426]	eval-error:0.2078	train-error:0.113401
# [427]	eval-error:0.20832	train-error:0.113204
# [428]	eval-error:0.20816	train-error:0.11312
# [429]	eval-error:0.20828	train-error:0.112838
# [430]	eval-error:0.20804	train-error:0.112753
# [431]	eval-error:0.20792	train-error:0.112631
# [432]	eval-error:0.20784	train-error:0.112593
# [433]	eval-error:0.2082	train-error:0.112443
# [434]	eval-error:0.20816	train-error:0.112406
# [435]	eval-error:0.20812	train-error:0.112312
# [436]	eval-error:0.20792	train-error:0.112124
# [437]	eval-error:0.20784	train-error:0.112067
# [438]	eval-error:0.20784	train-error:0.111964
# [439]	eval-error:0.20776	train-error:0.111908
# [440]	eval-error:0.20776	train-error:0.111842
# [441]	eval-error:0.20796	train-error:0.111795
# [442]	eval-error:0.20756	train-error:0.111645
# [443]	eval-error:0.20756	train-error:0.111598
# [444]	eval-error:0.20788	train-error:0.111381
# [445]	eval-error:0.20768	train-error:0.111278
# [446]	eval-error:0.2076	train-error:0.111203
# [447]	eval-error:0.20768	train-error:0.111118
# [448]	eval-error:0.2076	train-error:0.111175
# [449]	eval-error:0.20768	train-error:0.110968
# [450]	eval-error:0.20756	train-error:0.110902
# [451]	eval-error:0.20732	train-error:0.11063
# [452]	eval-error:0.2072	train-error:0.110545
# [453]	eval-error:0.20716	train-error:0.110517
# [454]	eval-error:0.2072	train-error:0.110489
# [455]	eval-error:0.20704	train-error:0.110216
# [456]	eval-error:0.20664	train-error:0.110226
# [457]	eval-error:0.20672	train-error:0.110169
# [458]	eval-error:0.20668	train-error:0.110094
# [459]	eval-error:0.20664	train-error:0.110076
# [460]	eval-error:0.20668	train-error:0.110057
# [461]	eval-error:0.20684	train-error:0.109812
# [462]	eval-error:0.2066	train-error:0.109747
# [463]	eval-error:0.20644	train-error:0.109587
# [464]	eval-error:0.2062	train-error:0.109361
# [465]	eval-error:0.20636	train-error:0.109296
# [466]	eval-error:0.20648	train-error:0.109268
# [467]	eval-error:0.20648	train-error:0.109277
# [468]	eval-error:0.20672	train-error:0.109296
# [469]	eval-error:0.2066	train-error:0.109192
# [470]	eval-error:0.20672	train-error:0.10908
# [471]	eval-error:0.20664	train-error:0.10908
# [472]	eval-error:0.20664	train-error:0.108967
# [473]	eval-error:0.20628	train-error:0.108704
# [474]	eval-error:0.20628	train-error:0.108704
# [475]	eval-error:0.20664	train-error:0.108262
# [476]	eval-error:0.2064	train-error:0.108149
# [477]	eval-error:0.20632	train-error:0.108112
# [478]	eval-error:0.20644	train-error:0.108074
# [479]	eval-error:0.20664	train-error:0.108027
# [480]	eval-error:0.20664	train-error:0.107905
# [481]	eval-error:0.2066	train-error:0.107868
# [482]	eval-error:0.20644	train-error:0.107764
# [483]	eval-error:0.20636	train-error:0.107736
# [484]	eval-error:0.20592	train-error:0.107595
# [485]	eval-error:0.206	train-error:0.107529
# [486]	eval-error:0.20588	train-error:0.107445
# [487]	eval-error:0.20584	train-error:0.107454
# [488]	eval-error:0.20576	train-error:0.10721
# [489]	eval-error:0.20536	train-error:0.107107
# [490]	eval-error:0.20528	train-error:0.107022
# [491]	eval-error:0.20512	train-error:0.106815
# [492]	eval-error:0.20512	train-error:0.106768
# [493]	eval-error:0.20516	train-error:0.106609
# [494]	eval-error:0.20528	train-error:0.10643
# [495]	eval-error:0.20524	train-error:0.106327
# [496]	eval-error:0.20532	train-error:0.106242
# [497]	eval-error:0.20532	train-error:0.106214
# [498]	eval-error:0.20516	train-error:0.106176
# [499]	eval-error:0.2054	train-error:0.106073
# [500]	eval-error:0.2054	train-error:0.106045
# [501]	eval-error:0.20512	train-error:0.105904
# [502]	eval-error:0.20484	train-error:0.105866
# [503]	eval-error:0.2048	train-error:0.105876
# [504]	eval-error:0.205	train-error:0.105744
# [505]	eval-error:0.20472	train-error:0.105641
# [506]	eval-error:0.20476	train-error:0.10566
# [507]	eval-error:0.2046	train-error:0.105632
# [508]	eval-error:0.2044	train-error:0.105575
# [509]	eval-error:0.20456	train-error:0.1055
# [510]	eval-error:0.20488	train-error:0.105303
# [511]	eval-error:0.20468	train-error:0.105246
# [512]	eval-error:0.20464	train-error:0.105246
# [513]	eval-error:0.20456	train-error:0.10519
# [514]	eval-error:0.20456	train-error:0.105162
# [515]	eval-error:0.20468	train-error:0.105171
# [516]	eval-error:0.20492	train-error:0.105124
# [517]	eval-error:0.205	train-error:0.105181
# [518]	eval-error:0.20512	train-error:0.104964
# [519]	eval-error:0.20504	train-error:0.104871
# [520]	eval-error:0.205	train-error:0.104777
# [521]	eval-error:0.2048	train-error:0.10473
# [522]	eval-error:0.20484	train-error:0.104617
# [523]	eval-error:0.20468	train-error:0.104607
# [524]	eval-error:0.20448	train-error:0.104617
# [525]	eval-error:0.20456	train-error:0.104532
# [526]	eval-error:0.20468	train-error:0.104532
# [527]	eval-error:0.2048	train-error:0.10441
# [528]	eval-error:0.205	train-error:0.104344
# [529]	eval-error:0.20484	train-error:0.104279
# [530]	eval-error:0.20456	train-error:0.104044
# [531]	eval-error:0.20456	train-error:0.10395
# [532]	eval-error:0.20448	train-error:0.103969
# [533]	eval-error:0.20436	train-error:0.103978
# [534]	eval-error:0.20448	train-error:0.103922
# [535]	eval-error:0.20452	train-error:0.103912
# [536]	eval-error:0.20456	train-error:0.103818
# [537]	eval-error:0.20448	train-error:0.103828
# [538]	eval-error:0.20488	train-error:0.103743
# [539]	eval-error:0.20484	train-error:0.103621
# [540]	eval-error:0.2048	train-error:0.103659
# [541]	eval-error:0.20444	train-error:0.103292
# [542]	eval-error:0.20452	train-error:0.103245
# [543]	eval-error:0.20436	train-error:0.103179
# [544]	eval-error:0.20448	train-error:0.103208
# [545]	eval-error:0.20444	train-error:0.103189
# [546]	eval-error:0.20412	train-error:0.103198
# [547]	eval-error:0.20424	train-error:0.103161
# [548]	eval-error:0.20376	train-error:0.102973
# [549]	eval-error:0.20372	train-error:0.102926
# [550]	eval-error:0.20356	train-error:0.102898
# [551]	eval-error:0.20368	train-error:0.102794
# [552]	eval-error:0.20356	train-error:0.102719
# [553]	eval-error:0.20364	train-error:0.10271
# [554]	eval-error:0.20348	train-error:0.102719
# [555]	eval-error:0.20344	train-error:0.1027
# [556]	eval-error:0.20352	train-error:0.102644
# [557]	eval-error:0.20348	train-error:0.102691
# [558]	eval-error:0.20364	train-error:0.102644
# [559]	eval-error:0.20352	train-error:0.102616
# [560]	eval-error:0.20364	train-error:0.10254
# [561]	eval-error:0.2036	train-error:0.102371
# [562]	eval-error:0.2036	train-error:0.102277
# [563]	eval-error:0.20348	train-error:0.102155
# [564]	eval-error:0.20336	train-error:0.102061
# [565]	eval-error:0.20336	train-error:0.101996
# [566]	eval-error:0.20324	train-error:0.101902
# [567]	eval-error:0.2032	train-error:0.101845
# [568]	eval-error:0.20304	train-error:0.101798
# [569]	eval-error:0.20292	train-error:0.101704
# [570]	eval-error:0.20296	train-error:0.101648
# [571]	eval-error:0.20296	train-error:0.101563
# [572]	eval-error:0.20324	train-error:0.101441
# [573]	eval-error:0.20316	train-error:0.101385
# [574]	eval-error:0.20308	train-error:0.101206
# [575]	eval-error:0.20304	train-error:0.101065
# [576]	eval-error:0.20304	train-error:0.10099
# [577]	eval-error:0.2028	train-error:0.100971
# [578]	eval-error:0.20304	train-error:0.100849
# [579]	eval-error:0.20304	train-error:0.100868
# [580]	eval-error:0.2028	train-error:0.100727
# [581]	eval-error:0.20276	train-error:0.100614
# [582]	eval-error:0.20268	train-error:0.100483
# [583]	eval-error:0.20272	train-error:0.100351
# [584]	eval-error:0.20268	train-error:0.100286
# [585]	eval-error:0.20268	train-error:0.100248
# [586]	eval-error:0.20272	train-error:0.100145
# [587]	eval-error:0.2028	train-error:0.100032
# [588]	eval-error:0.20276	train-error:0.100041
# [589]	eval-error:0.2028	train-error:0.099976
# [590]	eval-error:0.20276	train-error:0.099835
# [591]	eval-error:0.20276	train-error:0.099806
# [592]	eval-error:0.20284	train-error:0.099703
# [593]	eval-error:0.203	train-error:0.099656
# [594]	eval-error:0.20304	train-error:0.099384
# [595]	eval-error:0.20308	train-error:0.099337
# [596]	eval-error:0.20328	train-error:0.099074
# [597]	eval-error:0.20328	train-error:0.099017
# [598]	eval-error:0.2032	train-error:0.098858
# [599]	eval-error:0.20312	train-error:0.098773
# [600]	eval-error:0.20296	train-error:0.09866
# [601]	eval-error:0.20304	train-error:0.09867
# [602]	eval-error:0.203	train-error:0.098651
# [603]	eval-error:0.20304	train-error:0.098623
# [604]	eval-error:0.20288	train-error:0.098566
# [605]	eval-error:0.20296	train-error:0.098538
# [606]	eval-error:0.20284	train-error:0.098547
# [607]	eval-error:0.20284	train-error:0.098284
# [608]	eval-error:0.20284	train-error:0.098237
# [609]	eval-error:0.20304	train-error:0.098209
# [610]	eval-error:0.20296	train-error:0.098172
# [611]	eval-error:0.20312	train-error:0.098125
# [612]	eval-error:0.20292	train-error:0.098021
# [613]	eval-error:0.2026	train-error:0.097937
# [614]	eval-error:0.20256	train-error:0.097899
# [615]	eval-error:0.20244	train-error:0.097899
# [616]	eval-error:0.20252	train-error:0.097711
# [617]	eval-error:0.20252	train-error:0.097439
# [618]	eval-error:0.20272	train-error:0.097458
# [619]	eval-error:0.20264	train-error:0.097429
# [620]	eval-error:0.20252	train-error:0.097326
# [621]	eval-error:0.20252	train-error:0.097317
# [622]	eval-error:0.20256	train-error:0.097185
# [623]	eval-error:0.20256	train-error:0.097223
# [624]	eval-error:0.2026	train-error:0.097119
# [625]	eval-error:0.20288	train-error:0.097044
# [626]	eval-error:0.20276	train-error:0.097007
# [627]	eval-error:0.20248	train-error:0.096988
# [628]	eval-error:0.20256	train-error:0.096913
# [629]	eval-error:0.20244	train-error:0.096847
# [630]	eval-error:0.20256	train-error:0.096809
# [631]	eval-error:0.20256	train-error:0.096838
# [632]	eval-error:0.20248	train-error:0.096772
# [633]	eval-error:0.20232	train-error:0.096631
# [634]	eval-error:0.20212	train-error:0.096603
# [635]	eval-error:0.2024	train-error:0.096481
# [636]	eval-error:0.2026	train-error:0.096518
# [637]	eval-error:0.2026	train-error:0.096462
# [638]	eval-error:0.20252	train-error:0.096537
# [639]	eval-error:0.20248	train-error:0.096509
# [640]	eval-error:0.20244	train-error:0.096368
# [641]	eval-error:0.2022	train-error:0.096293
# [642]	eval-error:0.20224	train-error:0.096264
# [643]	eval-error:0.20212	train-error:0.096227
# [644]	eval-error:0.20204	train-error:0.096264
# [645]	eval-error:0.20204	train-error:0.096199
# [646]	eval-error:0.20196	train-error:0.096227
# [647]	eval-error:0.20204	train-error:0.096152
# [648]	eval-error:0.20196	train-error:0.096105
# [649]	eval-error:0.20212	train-error:0.09603
# [650]	eval-error:0.2022	train-error:0.095907
# [651]	eval-error:0.20212	train-error:0.095889
# [652]	eval-error:0.20216	train-error:0.095795
# [653]	eval-error:0.20152	train-error:0.095438
# [654]	eval-error:0.20192	train-error:0.095297
# [655]	eval-error:0.20188	train-error:0.095287
# [656]	eval-error:0.2018	train-error:0.095184
# [657]	eval-error:0.20152	train-error:0.095165
# [658]	eval-error:0.2016	train-error:0.095052
# [659]	eval-error:0.20164	train-error:0.095034
# [660]	eval-error:0.20168	train-error:0.09494
# [661]	eval-error:0.202	train-error:0.09494
# [662]	eval-error:0.202	train-error:0.094893
# [663]	eval-error:0.20184	train-error:0.094742
# [664]	eval-error:0.20188	train-error:0.094658
# [665]	eval-error:0.2018	train-error:0.09462
# [666]	eval-error:0.20176	train-error:0.09463
# [667]	eval-error:0.2018	train-error:0.094592
# [668]	eval-error:0.2018	train-error:0.094526
# [669]	eval-error:0.2016	train-error:0.094395
# [670]	eval-error:0.20168	train-error:0.094404
# [671]	eval-error:0.20156	train-error:0.094376
# [672]	eval-error:0.20156	train-error:0.094273
# [673]	eval-error:0.2018	train-error:0.094244
# [674]	eval-error:0.20164	train-error:0.094226
# [675]	eval-error:0.20168	train-error:0.094216
# [676]	eval-error:0.20172	train-error:0.094169
# [677]	eval-error:0.20184	train-error:0.09416
# [678]	eval-error:0.202	train-error:0.094085
# [679]	eval-error:0.20184	train-error:0.094038
# [680]	eval-error:0.20184	train-error:0.093906
# [681]	eval-error:0.20164	train-error:0.09385
# [682]	eval-error:0.2014	train-error:0.093756
# [683]	eval-error:0.20168	train-error:0.093512
# [684]	eval-error:0.20164	train-error:0.093427
# [685]	eval-error:0.20168	train-error:0.093352
# [686]	eval-error:0.20156	train-error:0.093352
# [687]	eval-error:0.20156	train-error:0.093389
# [688]	eval-error:0.20156	train-error:0.093314
# [689]	eval-error:0.20144	train-error:0.093314
# [690]	eval-error:0.20152	train-error:0.093258
# [691]	eval-error:0.20188	train-error:0.09323
# [692]	eval-error:0.2018	train-error:0.093173
# [693]	eval-error:0.20188	train-error:0.093136
# [694]	eval-error:0.20184	train-error:0.093136
# [695]	eval-error:0.20164	train-error:0.093032
# [696]	eval-error:0.20164	train-error:0.093042
# [697]	eval-error:0.20168	train-error:0.092967
# [698]	eval-error:0.20156	train-error:0.092826
# [699]	eval-error:0.20152	train-error:0.092732
# [700]	eval-error:0.20156	train-error:0.092732
# [701]	eval-error:0.20176	train-error:0.092779
# [702]	eval-error:0.20176	train-error:0.092751
# [703]	eval-error:0.20168	train-error:0.092628
# [704]	eval-error:0.2018	train-error:0.092619
# [705]	eval-error:0.20184	train-error:0.092591
# [706]	eval-error:0.20176	train-error:0.092591
# [707]	eval-error:0.20204	train-error:0.092506
# [708]	eval-error:0.20192	train-error:0.092488
# [709]	eval-error:0.20188	train-error:0.092469
# [710]	eval-error:0.20192	train-error:0.092469
# [711]	eval-error:0.20184	train-error:0.092459
# [712]	eval-error:0.20196	train-error:0.092459
# [713]	eval-error:0.20184	train-error:0.092403
# [714]	eval-error:0.20156	train-error:0.092271
# [715]	eval-error:0.20136	train-error:0.092253
# [716]	eval-error:0.20148	train-error:0.092159
# [717]	eval-error:0.20168	train-error:0.092084
# [718]	eval-error:0.20196	train-error:0.092037
# [719]	eval-error:0.20212	train-error:0.092008
# [720]	eval-error:0.20212	train-error:0.091933
# [721]	eval-error:0.20196	train-error:0.09182
# [722]	eval-error:0.20164	train-error:0.091849
# [723]	eval-error:0.20164	train-error:0.091877
# [724]	eval-error:0.20156	train-error:0.091745
# [725]	eval-error:0.20156	train-error:0.091726
# [726]	eval-error:0.20168	train-error:0.091689
# [727]	eval-error:0.2016	train-error:0.09168
# [728]	eval-error:0.20148	train-error:0.091623
# [729]	eval-error:0.20136	train-error:0.091595
# [730]	eval-error:0.20136	train-error:0.091473
# [731]	eval-error:0.2014	train-error:0.091492
# [732]	eval-error:0.20156	train-error:0.091473
# [733]	eval-error:0.20128	train-error:0.091426
# [734]	eval-error:0.20132	train-error:0.091416
# [735]	eval-error:0.20116	train-error:0.091416
# [736]	eval-error:0.2012	train-error:0.091379
# [737]	eval-error:0.20108	train-error:0.091332
# [738]	eval-error:0.201	train-error:0.091341
# [739]	eval-error:0.20104	train-error:0.0912
# [740]	eval-error:0.20112	train-error:0.091163
# [741]	eval-error:0.20116	train-error:0.091153
# [742]	eval-error:0.2014	train-error:0.091069
# [743]	eval-error:0.20128	train-error:0.09105
# [744]	eval-error:0.20112	train-error:0.090947
# [745]	eval-error:0.201	train-error:0.091041
# [746]	eval-error:0.201	train-error:0.090834
# [747]	eval-error:0.20124	train-error:0.090806
# [748]	eval-error:0.20128	train-error:0.090796
# [749]	eval-error:0.20116	train-error:0.090749
# [750]	eval-error:0.20116	train-error:0.090749
# [751]	eval-error:0.20176	train-error:0.090186
# [752]	eval-error:0.20192	train-error:0.09011
# [753]	eval-error:0.20188	train-error:0.09012
# [754]	eval-error:0.2018	train-error:0.090026
# [755]	eval-error:0.20168	train-error:0.090007
# [756]	eval-error:0.2016	train-error:0.089951
# [757]	eval-error:0.20156	train-error:0.089819
# [758]	eval-error:0.20144	train-error:0.089819
# [759]	eval-error:0.20152	train-error:0.089838
# [760]	eval-error:0.2014	train-error:0.089772
# [761]	eval-error:0.20144	train-error:0.089763
# [762]	eval-error:0.20136	train-error:0.089782
# [763]	eval-error:0.20124	train-error:0.089688
# [764]	eval-error:0.20128	train-error:0.089669
# [765]	eval-error:0.20124	train-error:0.089641
# [766]	eval-error:0.20156	train-error:0.08965
# [767]	eval-error:0.20164	train-error:0.089613
# [768]	eval-error:0.20172	train-error:0.089566
# [769]	eval-error:0.20168	train-error:0.089509
# [770]	eval-error:0.20156	train-error:0.089331
# [771]	eval-error:0.20148	train-error:0.089284
# [772]	eval-error:0.20172	train-error:0.089162
# [773]	eval-error:0.20164	train-error:0.089096
# [774]	eval-error:0.20164	train-error:0.089058
# [775]	eval-error:0.20164	train-error:0.089002
# [776]	eval-error:0.20152	train-error:0.088945
# [777]	eval-error:0.20152	train-error:0.088861
# [778]	eval-error:0.20128	train-error:0.088842
# [779]	eval-error:0.20136	train-error:0.088701
# [780]	eval-error:0.20168	train-error:0.088767
# [781]	eval-error:0.20132	train-error:0.088664
# [782]	eval-error:0.20144	train-error:0.088617
# [783]	eval-error:0.20128	train-error:0.088579
# [784]	eval-error:0.20132	train-error:0.08856
# [785]	eval-error:0.20144	train-error:0.088541
# [786]	eval-error:0.20148	train-error:0.088344
# [787]	eval-error:0.20148	train-error:0.088307
# [788]	eval-error:0.20152	train-error:0.088297
# [789]	eval-error:0.20132	train-error:0.088269
# [790]	eval-error:0.20124	train-error:0.088269
# [791]	eval-error:0.2012	train-error:0.088231
# [792]	eval-error:0.2012	train-error:0.088231
# [793]	eval-error:0.20128	train-error:0.088147
# [794]	eval-error:0.20132	train-error:0.088109
# [795]	eval-error:0.20148	train-error:0.088119
# [796]	eval-error:0.20136	train-error:0.088147
# [797]	eval-error:0.2014	train-error:0.088109
# [798]	eval-error:0.20124	train-error:0.088034
# [799]	eval-error:0.20128	train-error:0.087959
# [800]	eval-error:0.20096	train-error:0.08794
# [801]	eval-error:0.201	train-error:0.087846
# [802]	eval-error:0.20108	train-error:0.087874
# [803]	eval-error:0.20108	train-error:0.087762
# [804]	eval-error:0.20108	train-error:0.087771
# [805]	eval-error:0.201	train-error:0.087686
# [806]	eval-error:0.201	train-error:0.087677
# [807]	eval-error:0.20092	train-error:0.087705
# [808]	eval-error:0.20076	train-error:0.087705
# [809]	eval-error:0.20092	train-error:0.087668
# [810]	eval-error:0.201	train-error:0.08763
# [811]	eval-error:0.20092	train-error:0.087658
# [812]	eval-error:0.20116	train-error:0.087621
# [813]	eval-error:0.2012	train-error:0.087555
# [814]	eval-error:0.2012	train-error:0.08748
# [815]	eval-error:0.20116	train-error:0.08747
# [816]	eval-error:0.20116	train-error:0.087442
# [817]	eval-error:0.20144	train-error:0.087358
# [818]	eval-error:0.20156	train-error:0.087339
# [819]	eval-error:0.20164	train-error:0.087329
# [820]	eval-error:0.20152	train-error:0.08732
# [821]	eval-error:0.20168	train-error:0.087245
# [822]	eval-error:0.20196	train-error:0.087132
# [823]	eval-error:0.202	train-error:0.087142
# [824]	eval-error:0.20192	train-error:0.087057
# [825]	eval-error:0.20152	train-error:0.086916
# [826]	eval-error:0.2016	train-error:0.086738
# [827]	eval-error:0.20156	train-error:0.086615
# [828]	eval-error:0.20148	train-error:0.086578
# [829]	eval-error:0.20148	train-error:0.086493
# [830]	eval-error:0.2016	train-error:0.086503
# [831]	eval-error:0.20148	train-error:0.086475
# [832]	eval-error:0.20164	train-error:0.086465
# [833]	eval-error:0.20152	train-error:0.08639
# [834]	eval-error:0.20156	train-error:0.086371
# [835]	eval-error:0.20156	train-error:0.086249
# [836]	eval-error:0.20128	train-error:0.086258
# [837]	eval-error:0.20132	train-error:0.08624
# [838]	eval-error:0.20116	train-error:0.08623
# [839]	eval-error:0.20128	train-error:0.086117
# [840]	eval-error:0.20116	train-error:0.086117
# [841]	eval-error:0.20128	train-error:0.086061
# [842]	eval-error:0.20128	train-error:0.086042
# [843]	eval-error:0.20132	train-error:0.085911
# [844]	eval-error:0.20124	train-error:0.085873
# [845]	eval-error:0.2014	train-error:0.085873
# [846]	eval-error:0.20128	train-error:0.08593
# [847]	eval-error:0.2014	train-error:0.085911
# [848]	eval-error:0.20144	train-error:0.085836
# [849]	eval-error:0.20128	train-error:0.085798
# [850]	eval-error:0.20128	train-error:0.085723
# [851]	eval-error:0.20124	train-error:0.085676
# [852]	eval-error:0.20144	train-error:0.085695
# [853]	eval-error:0.20152	train-error:0.085591
# [854]	eval-error:0.20144	train-error:0.085544
# [855]	eval-error:0.2014	train-error:0.085516
# [856]	eval-error:0.20132	train-error:0.085441
# [857]	eval-error:0.20124	train-error:0.085403
# [858]	eval-error:0.2012	train-error:0.085394
# [859]	eval-error:0.20124	train-error:0.085394
# [860]	eval-error:0.2014	train-error:0.085263
# [861]	eval-error:0.2016	train-error:0.08514
# [862]	eval-error:0.2014	train-error:0.085178
# [863]	eval-error:0.2014	train-error:0.085159
# [864]	eval-error:0.20136	train-error:0.085159
# [865]	eval-error:0.20136	train-error:0.085178
# [866]	eval-error:0.20132	train-error:0.08515
# [867]	eval-error:0.20104	train-error:0.085159
# [868]	eval-error:0.20112	train-error:0.085216
# [869]	eval-error:0.20124	train-error:0.085178
# [870]	eval-error:0.2012	train-error:0.08515
# [871]	eval-error:0.2012	train-error:0.085046
# [872]	eval-error:0.20104	train-error:0.085037
# [873]	eval-error:0.20096	train-error:0.084981
# [874]	eval-error:0.20092	train-error:0.08499
# [875]	eval-error:0.20084	train-error:0.084943
# [876]	eval-error:0.20092	train-error:0.084915
# [877]	eval-error:0.20092	train-error:0.08483
# [878]	eval-error:0.201	train-error:0.084736
# [879]	eval-error:0.201	train-error:0.084802
# [880]	eval-error:0.201	train-error:0.084727
# [881]	eval-error:0.20084	train-error:0.084727
# [882]	eval-error:0.20076	train-error:0.084708
# [883]	eval-error:0.20076	train-error:0.084802
# [884]	eval-error:0.2006	train-error:0.084765
# [885]	eval-error:0.20072	train-error:0.084642
# [886]	eval-error:0.20096	train-error:0.084652
# [887]	eval-error:0.20112	train-error:0.084624
# [888]	eval-error:0.20128	train-error:0.084577
# [889]	eval-error:0.20116	train-error:0.084671
# [890]	eval-error:0.20116	train-error:0.084652
# [891]	eval-error:0.201	train-error:0.084699
# [892]	eval-error:0.20108	train-error:0.084736
# [893]	eval-error:0.201	train-error:0.084699
# [894]	eval-error:0.20088	train-error:0.084671
# [895]	eval-error:0.20092	train-error:0.084652
# [896]	eval-error:0.20096	train-error:0.084652
# [897]	eval-error:0.20112	train-error:0.084624
# [898]	eval-error:0.2014	train-error:0.084558
# [899]	eval-error:0.20136	train-error:0.084605
# [900]	eval-error:0.20136	train-error:0.084548
# [901]	eval-error:0.20136	train-error:0.084511
# [902]	eval-error:0.2014	train-error:0.08437
# [903]	eval-error:0.20144	train-error:0.084257
# [904]	eval-error:0.20156	train-error:0.084229
# [905]	eval-error:0.20128	train-error:0.084191
# [906]	eval-error:0.2012	train-error:0.084154
# [907]	eval-error:0.20116	train-error:0.084144
# [908]	eval-error:0.20108	train-error:0.084088
# [909]	eval-error:0.2012	train-error:0.084097
# [910]	eval-error:0.20136	train-error:0.084144
# [911]	eval-error:0.20116	train-error:0.084163
# [912]	eval-error:0.20132	train-error:0.084126
# [913]	eval-error:0.20116	train-error:0.084032
# [914]	eval-error:0.20116	train-error:0.084079
# [915]	eval-error:0.2012	train-error:0.0839
# [916]	eval-error:0.2012	train-error:0.0839
# [917]	eval-error:0.20128	train-error:0.083834
# [918]	eval-error:0.20148	train-error:0.08375
# [919]	eval-error:0.2014	train-error:0.083693
# [920]	eval-error:0.2012	train-error:0.083571
# [921]	eval-error:0.20124	train-error:0.083571
# [922]	eval-error:0.20116	train-error:0.083618
# [923]	eval-error:0.20112	train-error:0.0836
# [924]	eval-error:0.20088	train-error:0.083534
# [925]	eval-error:0.20092	train-error:0.083459
# [926]	eval-error:0.20108	train-error:0.083412
# [927]	eval-error:0.20108	train-error:0.083299
# [928]	eval-error:0.20116	train-error:0.083318
# [929]	eval-error:0.2012	train-error:0.083271
# [930]	eval-error:0.201	train-error:0.08328
# [931]	eval-error:0.20096	train-error:0.083299
# [932]	eval-error:0.20084	train-error:0.083327
# [933]	eval-error:0.20092	train-error:0.083336
# [934]	eval-error:0.20096	train-error:0.083252
# [935]	eval-error:0.20104	train-error:0.083261
# [936]	eval-error:0.20108	train-error:0.08328
# [937]	eval-error:0.20112	train-error:0.083233
# [938]	eval-error:0.20104	train-error:0.08313
# [939]	eval-error:0.20108	train-error:0.083149
# [940]	eval-error:0.20096	train-error:0.083177
# [941]	eval-error:0.20112	train-error:0.083102
# [942]	eval-error:0.20104	train-error:0.08312
# [943]	eval-error:0.20112	train-error:0.083064
# [944]	eval-error:0.20096	train-error:0.083008
# [945]	eval-error:0.20092	train-error:0.082998
# [946]	eval-error:0.20064	train-error:0.082998
# [947]	eval-error:0.201	train-error:0.082839
# [948]	eval-error:0.20096	train-error:0.082745
# [949]	eval-error:0.2012	train-error:0.082547
# [950]	eval-error:0.20104	train-error:0.082406
# [951]	eval-error:0.201	train-error:0.082378
# [952]	eval-error:0.20096	train-error:0.082331
# [953]	eval-error:0.20068	train-error:0.082303
# [954]	eval-error:0.20064	train-error:0.082275
# [955]	eval-error:0.20068	train-error:0.082218
# [956]	eval-error:0.20068	train-error:0.0822
# [957]	eval-error:0.20048	train-error:0.082059
# [958]	eval-error:0.20044	train-error:0.08189
# [959]	eval-error:0.2004	train-error:0.081767
# [960]	eval-error:0.20048	train-error:0.08173
# [961]	eval-error:0.20032	train-error:0.081636
# [962]	eval-error:0.20016	train-error:0.081551
# [963]	eval-error:0.20028	train-error:0.081523
# [964]	eval-error:0.2002	train-error:0.081504
# [965]	eval-error:0.20024	train-error:0.081542
# [966]	eval-error:0.20016	train-error:0.081542
# [967]	eval-error:0.20036	train-error:0.081504
# [968]	eval-error:0.20052	train-error:0.081504
# [969]	eval-error:0.20044	train-error:0.081486
# [970]	eval-error:0.20056	train-error:0.081486
# [971]	eval-error:0.2006	train-error:0.081401
# [972]	eval-error:0.2008	train-error:0.081335
# [973]	eval-error:0.20068	train-error:0.081335
# [974]	eval-error:0.20068	train-error:0.08126
# [975]	eval-error:0.20072	train-error:0.081166
# [976]	eval-error:0.20064	train-error:0.081119
# [977]	eval-error:0.20064	train-error:0.081053
# [978]	eval-error:0.20044	train-error:0.081035
# [979]	eval-error:0.2004	train-error:0.080931
# [980]	eval-error:0.20052	train-error:0.0808
# [981]	eval-error:0.20044	train-error:0.080734
# [982]	eval-error:0.20036	train-error:0.080706
# [983]	eval-error:0.20008	train-error:0.080546
# [984]	eval-error:0.20032	train-error:0.080527
# [985]	eval-error:0.20052	train-error:0.08049
# [986]	eval-error:0.2006	train-error:0.080443
# [987]	eval-error:0.20048	train-error:0.080461
# [988]	eval-error:0.20028	train-error:0.080368
# [989]	eval-error:0.20024	train-error:0.080349
# [990]	eval-error:0.20036	train-error:0.080339
# [991]	eval-error:0.20028	train-error:0.08033
# [992]	eval-error:0.20048	train-error:0.080302
# [993]	eval-error:0.20048	train-error:0.080274
# [994]	eval-error:0.20064	train-error:0.080161
# [995]	eval-error:0.20052	train-error:0.080133
# [996]	eval-error:0.20052	train-error:0.08002
# [997]	eval-error:0.20076	train-error:0.079926
# [998]	eval-error:0.20076	train-error:0.079917
# [999]	eval-error:0.2006	train-error:0.079907
# Done.

# %%
#parameter tuning (example for eta)
#gridsearch = {}
#param_range = [0.2, 0.25]
#for parameter in param_range:
#    evallist  = [(dval,'eval'), (dtrain,'train')]
#    param['eta']=parameter
#    bst = xgb.train(param, dtrain, num_round, evallist )
#    predictions = [1 if x > 0.5 else 0 for x in bst.predict(dval)]
#    score = accuracy_score(predictions, test['label'][:10000])
#    gridsearch[parameter]=score

#gridsearch = [(value, key) for key, value in gridsearch.items()]
#print("Best parameter: ", max(gridsearch)[1])
#print("Best accuracy: ", max(gridsearch)[0])

# %%
#predict
predictions = bst.predict(dtest) 
predictions = [1 if x > 0.5 else 0 for x in predictions] 
score = accuracy_score(predictions, test['label'][25000:])
print("Test set accuracy: ",score)
# Out:
# Test set accuracy:  0.802290333446
